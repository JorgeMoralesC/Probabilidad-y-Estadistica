# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeMoralesC/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# # Unidad 1
# # Practica 3. Tabla de frecuencias y regla de sturges
# ## Docente: José Gabriel Rodríguez Rivas
# ## Alumno: Jorge Lauro Morales Romero

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [52, 68, 23, 29, 24, 49, 61, 26, 61, 55, 34, 65, 37, 28, 48, 41, 60, 48, 25, 50, 70, 66, 67, 46, 39, 49, 43, 43, 26, 25, 53, 25, 23, 58, 68, 28, 42, 63, 58, 59, 70, 65, 48, 43, 54, 60, 63, 65, 19, 62, 37, 36, 36, 63, 59, 49, 21, 21, 65, 45, 23, 52, 51, 25, 19, 37, 28, 65, 48, 27, 49, 34, 32, 33, 31, 21, 42, 28, 65, 46, 19, 59, 30, 70, 37, 38, 56, 37, 57, 44, 68, 70, 65, 24, 63, 56, 49, 29, 29, 39]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    52
# 1    68
# 2    23
# 3    29
# 4    24

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de distribucion de frecuencias ")
tabla_frecuencias
# Out:
# Tabla de distribucion de frecuencias
#     Edad  Frecuencia
# 14    19           3
# 13    21           3
# 9     23           3
# 18    24           2
# 7     25           4
# 19    26           2
# 37    27           1
# 3     28           4
# 10    29           3
# 41    30           1
# 39    31           1
# 38    32           1
# 40    33           1
# 16    34           2
# 26    36           2
# 2     37           5
# 42    38           1
# 22    39           2
# 28    41           1
# 15    42           2
# 8     43           3
# 44    44           1
# 34    45           1
# 25    46           2
# 4     48           4
# 1     49           5
# 30    50           1
# 35    51           1
# 17    52           2
# 29    53           1
# 36    54           1
# 27    55           1
# 21    56           2
# 43    57           1
# 23    58           2
# 11    59           3
# 24    60           2
# 20    61           2
# 33    62           1
# 5     63           4
# 0     65           7
# 31    66           1
# 32    67           1
# 12    68           3
# 6     70           4

# %%
tabla_frecuencias['Frec relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa
# 14    19           3           0.03
# 13    21           3           0.03
# 9     23           3           0.03
# 18    24           2           0.02
# 7     25           4           0.04
# 19    26           2           0.02
# 37    27           1           0.01
# 3     28           4           0.04
# 10    29           3           0.03
# 41    30           1           0.01
# 39    31           1           0.01
# 38    32           1           0.01
# 40    33           1           0.01
# 16    34           2           0.02
# 26    36           2           0.02
# 2     37           5           0.05
# 42    38           1           0.01
# 22    39           2           0.02
# 28    41           1           0.01
# 15    42           2           0.02
# 8     43           3           0.03
# 44    44           1           0.01
# 34    45           1           0.01
# 25    46           2           0.02
# 4     48           4           0.04
# 1     49           5           0.05
# 30    50           1           0.01
# 35    51           1           0.01
# 17    52           2           0.02
# 29    53           1           0.01
# 36    54           1           0.01
# 27    55           1           0.01
# 21    56           2           0.02
# 43    57           1           0.01
# 23    58           2           0.02
# 11    59           3           0.03
# 24    60           2           0.02
# 20    61           2           0.02
# 33    62           1           0.01
# 5     63           4           0.04
# 0     65           7           0.07
# 31    66           1           0.01
# 32    67           1           0.01
# 12    68           3           0.03
# 6     70           4           0.04

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia']/100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec Porcentual
# 14    19           3           0.03              3.0
# 13    21           3           0.03              3.0
# 9     23           3           0.03              3.0
# 18    24           2           0.02              2.0
# 7     25           4           0.04              4.0
# 19    26           2           0.02              2.0
# 37    27           1           0.01              1.0
# 3     28           4           0.04              4.0
# 10    29           3           0.03              3.0
# 41    30           1           0.01              1.0
# 39    31           1           0.01              1.0
# 38    32           1           0.01              1.0
# 40    33           1           0.01              1.0
# 16    34           2           0.02              2.0
# 26    36           2           0.02              2.0
# 2     37           5           0.05              5.0
# 42    38           1           0.01              1.0
# 22    39           2           0.02              2.0
# 28    41           1           0.01              1.0
# 15    42           2           0.02              2.0
# 8     43           3           0.03              3.0
# 44    44           1           0.01              1.0
# 34    45           1           0.01              1.0
# 25    46           2           0.02              2.0
# 4     48           4           0.04              4.0
# 1     49           5           0.05              5.0
# 30    50           1           0.01              1.0
# 35    51           1           0.01              1.0
# 17    52           2           0.02              2.0
# 29    53           1           0.01              1.0
# 36    54           1           0.01              1.0
# 27    55           1           0.01              1.0
# 21    56           2           0.02              2.0
# 43    57           1           0.01              1.0
# 23    58           2           0.02              2.0
# 11    59           3           0.03              3.0
# 24    60           2           0.02              2.0
# 20    61           2           0.02              2.0
# 33    62           1           0.01              1.0
# 5     63           4           0.04              4.0
# 0     65           7           0.07              7.0
# 31    66           1           0.01              1.0
# 32    67           1           0.01              1.0
# 12    68           3           0.03              3.0
# 6     70           4           0.04              4.0

# %%
tabla_frecuencias['Frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec relativa  Frec Porcentual  Frec acumulada
# 14    19           3           0.03              3.0               3
# 13    21           3           0.03              3.0               6
# 9     23           3           0.03              3.0               9
# 18    24           2           0.02              2.0              11
# 7     25           4           0.04              4.0              15
# 19    26           2           0.02              2.0              17
# 37    27           1           0.01              1.0              18
# 3     28           4           0.04              4.0              22
# 10    29           3           0.03              3.0              25
# 41    30           1           0.01              1.0              26
# 39    31           1           0.01              1.0              27
# 38    32           1           0.01              1.0              28
# 40    33           1           0.01              1.0              29
# 16    34           2           0.02              2.0              31
# 26    36           2           0.02              2.0              33
# 2     37           5           0.05              5.0              38
# 42    38           1           0.01              1.0              39
# 22    39           2           0.02              2.0              41
# 28    41           1           0.01              1.0              42
# 15    42           2           0.02              2.0              44
# 8     43           3           0.03              3.0              47
# 44    44           1           0.01              1.0              48
# 34    45           1           0.01              1.0              49
# 25    46           2           0.02              2.0              51
# 4     48           4           0.04              4.0              55
# 1     49           5           0.05              5.0              60
# 30    50           1           0.01              1.0              61
# 35    51           1           0.01              1.0              62
# 17    52           2           0.02              2.0              64
# 29    53           1           0.01              1.0              65
# 36    54           1           0.01              1.0              66
# 27    55           1           0.01              1.0              67
# 21    56           2           0.02              2.0              69
# 43    57           1           0.01              1.0              70
# 23    58           2           0.02              2.0              72
# 11    59           3           0.03              3.0              75
# 24    60           2           0.02              2.0              77
# 20    61           2           0.02              2.0              79
# 33    62           1           0.01              1.0              80
# 5     63           4           0.04              4.0              84
# 0     65           7           0.07              7.0              91
# 31    66           1           0.01              1.0              92
# 32    67           1           0.01              1.0              93
# 12    68           3           0.03              3.0              96
# 6     70           4           0.04              4.0             100

# %%
import math

# %%
print(edades)
# Out:
# [52, 68, 23, 29, 24, 49, 61, 26, 61, 55, 34, 65, 37, 28, 48, 41, 60, 48, 25, 50, 70, 66, 67, 46, 39, 49, 43, 43, 26, 25, 53, 25, 23, 58, 68, 28, 42, 63, 58, 59, 70, 65, 48, 43, 54, 60, 63, 65, 19, 62, 37, 36, 36, 63, 59, 49, 21, 21, 65, 45, 23, 52, 51, 25, 19, 37, 28, 65, 48, 27, 49, 34, 32, 33, 31, 21, 42, 28, 65, 46, 19, 59, 30, 70, 37, 38, 56, 37, 57, 44, 68, 70, 65, 24, 63, 56, 49, 29, 29, 39]

# %%
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     52
# 1     68
# 2     23
# 3     29
# 4     24
# ..   ...
# 95    56
# 96    49
# 97    29
# 98    29
# 99    39
#
# [100 rows x 1 columns]

# %%
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n =", n, "\nNumero de Intervalos =", k)
# Out:
# Valor de n = 100
# Numero de Intervalos = 7

# %%
tabla_frecuencias = pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0    (62.714, 70.0]    20
# 1  (18.948, 26.286]    17
# 2  (40.857, 48.143]    14
# 3  (55.429, 62.714]    13
# 4  (26.286, 33.571]    12
# 5  (33.571, 40.857]    12
# 6  (48.143, 55.429]    12

# %%
tabla_frecuencias = pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0    (62.714, 70.0]    20
# 1  (18.948, 26.286]    17
# 2  (40.857, 48.143]    14
# 3  (55.429, 62.714]    13
# 4  (26.286, 33.571]    12
# 5  (33.571, 40.857]    12
# 6  (48.143, 55.429]    12

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 1  (18.948, 26.286]    17
# 4  (26.286, 33.571]    12
# 5  (33.571, 40.857]    12
# 2  (40.857, 48.143]    14
# 6  (48.143, 55.429]    12
# 3  (55.429, 62.714]    13
# 0    (62.714, 70.0]    20

# %%
tabla_frecuencias['Frec Rel'] = tabla_frecuencias['Frec'] / n
tabla_frecuencias['Frec Porc'] = tabla_frecuencias['Frec'] / n * 100
tabla_frecuencias['Frec Ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac'] = tabla_frecuencias['Frec Rel'].cumsum()
tabla_frecuencias['Frec Porc Ac'] = tabla_frecuencias['Frec Porc'].cumsum()
print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (18.948, 26.286]    17      0.17       17.0       17         0.17
# 4  (26.286, 33.571]    12      0.12       12.0       29         0.29
# 5  (33.571, 40.857]    12      0.12       12.0       41         0.41
# 2  (40.857, 48.143]    14      0.14       14.0       55         0.55
# 6  (48.143, 55.429]    12      0.12       12.0       67         0.67
# 3  (55.429, 62.714]    13      0.13       13.0       80         0.80
# 0    (62.714, 70.0]    20      0.20       20.0      100         1.00
#
#    Frec Porc Ac
# 1          17.0
# 4          29.0
# 5          41.0
# 2          55.0
# 6          67.0
# 3          80.0
# 0         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha=0.5)
plt.title("Histograma de edades basado en la funcion multiplotlib con valores estandar ")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion multiplotlib con valores estandar ')

# %%
plt.hist(df['Edad'], bins=k, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
