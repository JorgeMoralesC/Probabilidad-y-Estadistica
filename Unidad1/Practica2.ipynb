# %% [markdown]
# <a href="https://colab.research.google.com/github/JorgeMoralesC/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# # Unidad 1
# # Practica 2. Maximo, minimo, rango y dispersion de datos
# ## Docente: José Gabriel Rodríguez Rivas
#
# ## Alumno: Jorge Lauro Morales Romero

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [77.59, 83.45, 72.64, 84.48, 58.29, 68.36, 59.49, 83.98, 52.04, 61.48, 94.33, 76.19, 89.48, 97.47, 93.3, 72.63, 70.79, 51.55, 98.44, 76.27, 65.37, 67.72, 98.25, 96.12, 81.24, 91.64, 58.34, 61.65, 76.37, 52.73, 67.39, 77.89, 95.33, 77.24, 87.43, 72.11, 90.45, 65.98, 53.82, 95.51, 53.13, 89.31, 70.03, 64.79, 76.91, 59.85, 82.36, 69.39, 91.71, 53.66, 97.64, 72.24, 63.77, 75.19, 86.29, 64.1, 58.55, 55.84, 97.01, 72.16, 59.71, 67.8, 96.28, 68.34, 77.92, 67.64, 67.6, 72.26, 93.36, 62.58, 85.81, 55.85, 55.91, 60.59, 69.88, 86.92, 81.55, 78.68, 86.84, 85.11, 77.05, 53.45, 84.98, 77.22, 65.52, 90.15, 50.34, 85.05, 56.74, 75.28, 58.45, 66.54, 52.06, 86.64, 91.99, 91.1, 54.45, 83.25, 99.89, 90.18]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio = round(random.uniform(70, 100), 2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [80.98, 96.93, 83.25, 89.13, 91.01, 98.19, 90.21, 83.65, 71.29, 74.13, 82.33, 72.6, 96.17, 90.64, 75.08, 87.73, 74.62, 91.41, 78.4, 97.52, 99.07, 84.4, 94.77, 91.5, 74.39, 90.14, 86.9, 76.4, 85.29, 97.93, 77.88, 70.23, 71.9, 80.85, 70.33, 71.19, 84.77, 98.37, 77.35, 98.64, 87.79, 87.31, 92.15, 91.23, 78.67, 88.14, 74.63, 87.33, 80.63, 90.95, 73.84, 76.74, 73.11, 93.29, 91.42, 98.56, 96.07, 97.22, 91.45, 98.53, 96.67, 90.01, 85.09, 85.08, 98.45, 90.31, 81.5, 70.15, 81.12, 81.22, 92.86, 83.2, 83.35, 75.32, 83.47, 86.71, 82.86, 71.39, 77.81, 73.89, 77.71, 92.81, 75.51, 79.68, 86.91, 77.31, 86.95, 83.8, 83.04, 70.87, 80.4, 87.11, 92.22, 71.08, 70.12, 95.04, 87.54, 79.12, 96.35, 71.18]

# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
desviacion_estandar_fabrica1 = stdev(fabrica1)
print( "Estadistica descriptiva de la fabrica 1 \n", "media =", media1, "\n mediana 1 =", mediana1, "\n moda 1 =", moda1, "\n maximo 1 =", maximo1, "\n minimo 1 =", minimo1, "\n rango 1 =", rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media = 74.7972
#  mediana 1 = 75.235
#  moda 1 = 77.59
#  maximo 1 = 99.89
#  minimo 1 = 50.34
#  rango 1 = 49.55
# 14.196317781222515

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
desviacion_estandar_fabrica2 = stdev(fabrica2)
print( "Estadistica descriptiva de la fabrica 2 \n", "media 2 =", media2, "\n mediana 2 =", mediana2, "\n moda 2 =", moda2, "\n maximo 2 =", maximo2, "\n minimo 2 =", minimo2, "\n rango 2 =", rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media 2 = 84.5184
#  mediana 2 = 84.58500000000001
#  moda 2 = 80.98
#  maximo 2 = 99.07
#  minimo 2 = 70.12
#  rango 2 = 28.94999999999999
# 8.731467151988983

# %% [markdown]
# # Dispersion de datos

# %%
plt.figure(figsize= (8,6))
plt.hist(fabrica1, alpha=0.2, color='b', edgecolor ="black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:,.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2,label=f'Mediana={mediana1:,.2f}')
plt.axvline(moda1, color='y',linestyle='dashed', linewidth=2, label=f'Moda={moda1:,.2f}')
plt.axvline(media1 - desviacion_estandar_fabrica1, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion diaria de la fabrica 1 ")
plt.legend()
plt.show()

# %%
plt.figure(figsize= (8,6))
plt.hist(fabrica2, alpha=0.2, color='b', edgecolor ="black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:,.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2,label=f'Mediana={mediana2:,.2f}')
plt.axvline(moda2, color='y',linestyle='dashed', linewidth=2, label=f'Moda={moda2:,.2f}')
plt.axvline(media2 - desviacion_estandar_fabrica2, color='black', linestyle='dashed', linewidth=2)
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title("Produccion diaria de la fabrica 2 ")
plt.legend()
plt.show()
